# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from environment.twodsurface import TwoDSurfaceEnv



env = TwoDSurfaceEnv(2, 8, 1)
env.render()
# Out:
# [(5.566565833732989, 1.5656889573377253), (3.8396343142732317, 5.495265875612135)]
# [(2.9884017511555268, 6.446972089624125), (2.287841868148832, 4.13052130033866)]

# %%
env.step([[1.0, 2.0], [2.0,2.0]])
env.render()
# Out:
# [(7, 3.0), (7, 4.0)]
# [(2.9884017511555268, 6.446972089624125), (2.287841868148832, 4.13052130033866)]
