# %%
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from environment.twodsurface import TwoDSurfaceEnv

# %load_ext autoreload
# %autoreload 2


env = TwoDSurfaceEnv(1, 8, 1, accepted_radius=1)
env.render()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [(2.3534946001652974, 6.732042341618262)]
# [(6.434546487551004, 1.2060264408914003)]

# %%
print(env.step([(2.0,0.0)]))
env.render()
# Out:
# distance
# 0.5322237652212435
# ([[0.7941868250206622, 0.2165052927022828, 0.8043183109438755, 0.15075330511142504]], [10], True)
# [(6.353494600165297, 1.7320423416182624)]
# [(6.434546487551004, 1.2060264408914003)]
